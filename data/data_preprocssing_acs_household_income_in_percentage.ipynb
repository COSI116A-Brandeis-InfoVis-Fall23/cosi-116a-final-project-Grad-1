# %%
import pandas as pd
import glob
import os

# rename csv files to its coresponding year before run this code, 'example: 2010.csv'

# Path to the folder containing the CSV files
folder_path = 'replace this to your folder path'

# Use glob to find all CSV files in the folder
csv_files = glob.glob(folder_path + '*.csv')

# Sort the list of csv files based on the year extracted from the filename
csv_files_sorted = sorted(csv_files, key=lambda x: int(os.path.basename(x).split('.')[0]))

# Initialize an empty list to store the data
data_list = []

# Process each file in sorted order
for file in csv_files_sorted:
    # Extract the year from the filename
    year = os.path.basename(file).split('.')[0]

    # Read the CSV file
    df = pd.read_csv(file)

    # Add a new 'Year' column with empty strings
    df['Year'] = ""

    # Find rows with 'Total:' in the first column (assuming the first column contains the 'Total:' entries)
    total_rows = df[df.iloc[:, 0] == 'Total:'].index

    # Set the 'Year' for these rows to the filename (year)
    df.loc[total_rows, 'Year'] = year

    # Append to the list
    data_list.append(df)

# Concatenate all dataframes
all_data = pd.concat(data_list)

# Drop a specific column if needed
all_data = all_data.drop('United States!!Margin of Error', axis=1)
# Rename Column
all_data = all_data.rename(columns={'United States!!Estimate':'Estimate'})


# Save the combined data to a new CSV file
all_data.to_csv("/content/drive/MyDrive/116_data/116c/HOUSEHOLD_INCOME_BY_GROSS_RENT_AS_PERCENTAGE_OF_HOUSEHOLD_INCOME_IN_THE_PAST_12_MONTHS.csv", index=False)

all_data
# Out:
#                   Label (Grouping)    Estimate  Year
# 0                           Total:  39,694,047  2010
# 1               Less than $10,000:   5,949,406
# 2           Less than 30.0 percent     397,418
# 3             30.0 percent or more   4,222,018
# 4                     Not computed   1,329,970
# ..                             ...         ...   ...
# 20                    Not computed     328,999
# 21                $75,000 or more:  14,210,679
# 22          Less than 30.0 percent  11,962,795
# 23            30.0 percent or more   1,711,312
# 24                    Not computed     536,572
#
# [300 rows x 3 columns]
